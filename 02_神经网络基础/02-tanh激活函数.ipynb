# %% [markdown]
# ## 📘 定义公式：
#
# $$
# \tanh(x) = \frac{e^x - e^{-x}}{e^x + e^{-x}}
# $$
#
# 也可以写成用 `sigmoid` 表达的形式：
#
# $$
# \tanh(x) = 2 \cdot \text{sigmoid}(2x) - 1
# $$
#
# ---
#
# ## 📈 函数图像：
#
# - 是一个 S 型曲线（类似 sigmoid，但范围不同）
# - 取值范围：**(-1, 1)**
# - 当 $ x \to -\infty $，$ \tanh(x) \to -1 $
# - 当 $ x \to +\infty $，$ \tanh(x) \to +1 $
# - 在 $ x=0 $ 时：$ \tanh(0) = 0 $
#
# ---
#
# ## ✅ 优点：
#
# - 相比 sigmoid，它是**零中心化的**（输出在 -1 到 1 之间），这对梯度更新更友好；
# - 在隐藏层中更常用，因为它能更好地保持正负分布；
#
# ---
#
# ## ❌ 缺点：
#
# - 也有 **梯度消失问题**：当输入很大或很小时，梯度趋近于 0；
# - 在很深的神经网络中，tanh 有时会导致训练变慢；
#
# ---
#
# ## 🧠 导数：
#
# $$
# \frac{d}{dx} \tanh(x) = 1 - \tanh^2(x)
# $$
#
# ## 📌 总结一句话：
#
# > `tanh` 是一个平滑的 S 型激活函数，输出范围在 -1 到 1，比 sigmoid 更“居中”，常用于隐藏层。

# %%
import torch
import matplotlib.pyplot as plt


plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

x = torch.linspace(start=-20, end=20, steps=1000)
y = torch.tanh(input=x)

_, axs = plt.subplots(1, 2)
axs[0].plot(x, y)
axs[0].grid()
axs[0].set_title("tanh激活函数")


x = torch.linspace(start=-20, end=20, steps=1000, requires_grad=True)
torch.tanh(x).sum().backward()
axs[1].plot(x.detach().numpy(), x.grad)
axs[1].grid()
axs[1].set_title("tanh导数")
plt.show()
