# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
img = np.zeros(shape=(200, 200, 3))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
img = torch.full(size=(200, 200, 3), fill_value=255)
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = plt.imread("./image/a.jpg")
print(img)
print(img.shape)
plt.imshow(img)
plt.axis('off')
# Out:
# [[[ 27  25  30]
#   [ 27  25  30]
#   [ 27  25  30]
#   ...
#   [ 92 117  88]
#   [ 96 122  93]
#   [109 135 106]]
#
#  [[ 27  25  30]
#   [ 27  25  30]
#   [ 27  25  30]
#   ...
#   [ 74  99  70]
#   [ 72  98  69]
#   [ 85 111  82]]
#
#  [[ 27  25  30]
#   [ 27  25  30]
#   [ 27  25  30]
#   ...
#   [ 63  87  61]
#   [ 63  89  62]
#   [ 81 107  80]]
#
#  ...
#
#  [[220 209 179]
#   [221 210 180]
#   [222 211 181]
#   ...
#   [229 222 193]
#   [230 223 194]
#   [230 223 194]]
#
#  [[220 209 179]
#   [221 210 180]
#   [222 211 181]
#   ...
#   [228 221 192]
#   [228 221 192]
#   [228 221 192]]
#
#  [[221 210 180]
#   [221 210 180]
#   [222 211 181]
#   ...
#   [225 218 189]
#   [225 218 189]
#   [224 217 188]]]
# (1000, 1000, 3)
# (np.float64(-0.5), np.float64(999.5), np.float64(999.5), np.float64(-0.5))
